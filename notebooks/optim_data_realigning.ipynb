# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-frequency-realignment-optimization-parameters" data-toc-modified-id="Data-frequency-realignment-optimization-parameters-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data frequency realignment optimization parameters</a></span></li><li><span><a href="#Run-optimization-(long)" data-toc-modified-id="Run-optimization-(long)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Run optimization (long)</a></span></li><li><span><a href="#Analyze-optimization-results" data-toc-modified-id="Analyze-optimization-results-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Analyze optimization results</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %%
import os
os.chdir("/home/tangir/crmbm/python/pastis")

from IPython import get_ipython
get_ipython().magic("clear")

import matplotlib.pylab as plt
import mrs.reco as reco
import mrs.log as log

import pandas as pd
import seaborn as sns
import itertools

plt.close("all")
plt.rcParams['figure.dpi'] = 75
plt.rcParams['figure.max_open_warning'] = 1000
plt.rcParams["figure.figsize"] = [11, 8]
# get_ipython().magic("matplotlib inline")
get_ipython().magic("matplotlib notebook")
log.setLevel(log.INFO)

# %% [markdown]
# ### Data frequency realignment optimization parameters

# %%
# %% optim parameters
peak_snr_dict = {"NAA": [1.8, 2.2],
                 "Cre": [3, 3.15],
                 "Cho": [3.15, 3.3]}

df_list = []

realigning_moving_averages_list = [0, 1, 3, 5]
realigning_inter_corr_mode_list = [False, True]
realigning_freq_shift_max_list = [50, 100]
realigning_allowed_apodization_list = [0, 1, 5]

# %% [markdown]
# ### Run optimization (long)

# %%
realigning_big_list = itertools.product(realigning_moving_averages_list,
                      realigning_inter_corr_mode_list,
                      realigning_freq_shift_max_list,
                      realigning_allowed_apodization_list)

for (a, b, c, d) in realigning_big_list:

    p = reco.pipeline()
    p.settings["POI_range_ppm"] = [4.5, 5.2]
    p.settings["POI_shift_range_ppm"] = [1.8, 2.2]
    p.settings["POI_shift_true_ppm"] = 2.008
    p.settings["POI_LW_range_ppm"] = [4.5, 5.2]
    p.settings["realigning_inter_corr_mode"] = False
    p.settings["display"] = False


    if(a == 0):
        # no realignment job
        p.job_list = [  # p.job["displaying_anatomy"],
                    p.job["phasing"],
                    p.job["scaling"],
                    # p.job["FID modulus"],
                    p.job["channel_combining"],
                    # p.job["concatenate"],
                    # p.job["noise_estimation"],
                    p.job["zero_filling"],
                    # p.job["physio_analysis"],
                    # p.job["apodizing"],
                    p.job["averaging"],
                    p.job["apodizing"]
                    # p.job["calibrating"],
                    # p.job["water_removal"],
                    # p.job["cropping"],
                    # p.job["displaying"]
                    ]
    if(a > 0):
        p.job_list = [  # p.job["displaying_anatomy"],
                    p.job["phasing"],
                    p.job["scaling"],
                    # p.job["FID modulus"],
                    p.job["channel_combining"],
                    # p.job["concatenate"],
                    # p.job["noise_estimation"],
                    p.job["zero_filling"],
                    # p.job["physio_analysis"],
                    # p.job["apodizing"],
                    p.job["realigning"],
                    p.job["averaging"],
                    p.job["apodizing"]
                    # p.job["calibrating"],
                    # p.job["water_removal"],
                    # p.job["cropping"],
                    # p.job["displaying"]
                    ]
    

    p.job["realigning"]["moving_averages"] = a
    p.job["realigning"]["inter_corr_mode"] = b
    p.job["realigning"]["freq_shift_max"] = c
    p.job["realigning"]["allowed_apodization"] = d

    p.job["apodizing"]["damping_hz"] = 15

    p.analyze_enable = False

    # 26/06/2019 - 296_ym_p1_brainmoelle - Yasmin :)
    p.dataset[0]["legend"] = "sLASER R:N=20:1"
    p.dataset[0]["dcm"]["files"] = ["/home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0016_slaser-r-n",
                                    "/home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0015_slaser-r-n"]
    p.dataset[0]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID157_slaser_R_N=20+_1_longTE_SNR++++_FID34191.dat",
                                    "/home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID155_slaser_R_N=20+_1_longTE_SNR++++_FID34189.dat"]

    # 23/09/2019 - 313-ft-p1-moelle - Fransiska :|
    p.dataset[1]["legend"] = "sLASER 20:1"
    p.dataset[1]["resp_bpm"] = 12
    p.dataset[1]["dcm"]["files"] = ["/home/tangir/crmbm/acq/313-ft-p1-moelle/20190923/01_0011_slaser-r-n/original-primary_e09_0001.dcm",
                                    "/home/tangir/crmbm/acq/313-ft-p1-moelle/20190923/01_0010_slaser-r-n/original-primary_e09_0001.dcm"]
    p.dataset[1]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID68_slaser_R_N=20+_1_longTE_SNR++++_FID41500.dat",
                                    "/home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID65_slaser_R_N=20+_1_longTE_SNR++++_FID41497.dat"]

    # 25/09/2019 - 314-yt-p1-moelle - Yolanda :)))
    p.dataset[2]["legend"] = "sLASER 20:1"
    p.dataset[2]["resp_bpm"] = 17
    p.dataset[2]["heart_bpm"] = 75
    p.dataset[2]["dcm"]["files"] = ["/home/tangir/crmbm/acq/314-yt-p1-moelle/20190925/01_0010_slaser-r-n",
                                    "/home/tangir/crmbm/acq/314-yt-p1-moelle/20190925/01_0009_slaser-r-n"]
    p.dataset[2]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/314-yt-p1-moelle/meas_MID83_slaser_R_N=20+_1_longTE_SNR++++_FID41681.dat",
                                    "/home/tangir/crmbm/acq_twix/314-yt-p1-moelle/meas_MID81_slaser_R_N=20+_1_longTE_SNR++++_FID41679.dat"]
    p.dataset[2]["physio-file"] = "/home/tangir/crmbm/acq_physio/314_YT_P1_MOELLE_2.resp"

    # 05/09/2019 - 311-sl-p1-moelle - Simon :))
    p.dataset[3]["legend"] = "sLASER 20:1"
    p.dataset[3]["resp_bpm"] = 16
    p.dataset[3]["heart_bpm"] = 55
    p.dataset[3]["dcm"]["files"] = ["/home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0020_slaser-r-n",
                                    "/home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0018_slaser-r-n"]
    p.dataset[3]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID128_slaser_R_N=20+_1_longTE_SNR++++_FID39740.dat",
                                    "/home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID124_slaser_R_N=20+_1_longTE_SNR++++_FID39736.dat"]

    # 06/02/2019 - 349-ap-p1-moelle - Ahmad Fajar :|
    p.dataset[4]["legend"] = "sLASER 10:2 (REF with OVS)"
    p.dataset[4]["resp_bpm"] = 18
    p.dataset[4]["heart_bpm"] = 51
    p.dataset[4]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/349-ap-p1-moelle/meas_MID313_slaser_R_N=10_2_longTE_SNR+++_FID51947.dat",
                                    "/home/tangir/crmbm/acq_twix/349-ap-p1-moelle/meas_MID314_slaser_R_N=10_2_longTE_SNR+++_FID51948.dat"]
    p.dataset[4]["dcm"]["files"] = ["/home/tangir/crmbm/acq/349-ap-p1-moelle/20200206/01_0006_slaser-r-n/original-primary_e09_0001.dcm",
                                    "/home/tangir/crmbm/acq/349-ap-p1-moelle/20200206/01_0007_slaser-r-n/original-primary_e09_0001.dcm"]

    p.run()

    for this_dataset in p.dataset:
        this_df_row = {}
        this_df_row["patient"] = this_dataset["raw"]["data"].patient["name"]
        this_df_row["moving_averages"] = a
        this_df_row["inter_corr_mode"] = b
        this_df_row["freq_shift_max"] = c
        this_df_row["allowed_apodization"] = d
        this_df_row["lw"] = this_dataset["raw"]["data"].analyze_linewidth_1d(p.settings["POI_LW_range_ppm"], False, True)
        for this_peak_snr, this_peak_snr_range in peak_snr_dict.items():
            this_snr, this_s, _ = this_dataset["raw"]["data"].analyze_snr_1d(this_peak_snr_range, [-2, -1], True, False, True)
            plt.pause(0.1)
            this_df_row[this_peak_snr + "_s"] = this_s
            this_df_row[this_peak_snr + "_snr"] = this_snr

        df_list.append(this_df_row)

df = pd.DataFrame(df_list)
df.to_pickle("./notebooks/optim_data_realigning_results.pkl")
# Out:
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: checking datasets...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: dataset[0]:
# (INFO)  pipeline.run:   legend = sLASER R:N=20:1
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID157_slaser_R_N=20+_1_longTE_SNR++++_FID34191.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID155_slaser_R_N=20+_1_longTE_SNR++++_FID34189.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0016_slaser-r-n
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0015_slaser-r-n
# (INFO)  pipeline.run: dataset[1]:
# (INFO)  pipeline.run:   legend = sLASER 20:1
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID68_slaser_R_N=20+_1_longTE_SNR++++_FID41500.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID65_slaser_R_N=20+_1_longTE_SNR++++_FID41497.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/313-ft-p1-moelle/20190923/01_0011_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/313-ft-p1-moelle/20190923/01_0010_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  pipeline.run: dataset[2]:
# (INFO)  pipeline.run:   legend = sLASER 20:1
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/314-yt-p1-moelle/meas_MID83_slaser_R_N=20+_1_longTE_SNR++++_FID41681.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/314-yt-p1-moelle/meas_MID81_slaser_R_N=20+_1_longTE_SNR++++_FID41679.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/314-yt-p1-moelle/20190925/01_0010_slaser-r-n
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/314-yt-p1-moelle/20190925/01_0009_slaser-r-n
# (INFO)  pipeline.run: dataset[3]:
# (INFO)  pipeline.run:   legend = sLASER 20:1
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID128_slaser_R_N=20+_1_longTE_SNR++++_FID39740.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID124_slaser_R_N=20+_1_longTE_SNR++++_FID39736.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0020_slaser-r-n
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0018_slaser-r-n
# (INFO)  pipeline.run: dataset[4]:
# (INFO)  pipeline.run:   legend = sLASER 10:2 (REF with OVS)
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/349-ap-p1-moelle/meas_MID313_slaser_R_N=10_2_longTE_SNR+++_FID51947.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/349-ap-p1-moelle/meas_MID314_slaser_R_N=10_2_longTE_SNR+++_FID51948.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/349-ap-p1-moelle/20200206/01_0006_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/349-ap-p1-moelle/20200206/01_0007_slaser-r-n/original-primary_e09_0001.dcm
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data files...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER R:N=20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID157_slaser_R_N=20+_1_longTE_SNR++++_FID34191.dat
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 48
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 34
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 39
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 37
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 38
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 43
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 41
#   match = re.findall(rgx, header_string)
# (INFO)  reco.py.__new__: read a (128, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER R:N=20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID155_slaser_R_N=20+_1_longTE_SNR++++_FID34189.dat
# (INFO)  reco.py.__new__: read a (2, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (2, 8, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER R:N=20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0016_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER R:N=20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0015_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (1, 1, 4096) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID68_slaser_R_N=20+_1_longTE_SNR++++_FID41500.dat
# (INFO)  reco.py.__new__: read a (128, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID65_slaser_R_N=20+_1_longTE_SNR++++_FID41497.dat
# (INFO)  reco.py.__new__: read a (2, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (2, 8, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/313-ft-p1-moelle/20190923/01_0011_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/313-ft-p1-moelle/20190923/01_0010_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (1, 1, 4096) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/314-yt-p1-moelle/meas_MID83_slaser_R_N=20+_1_longTE_SNR++++_FID41681.dat
# (INFO)  reco.py.__new__: read a (128, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/314-yt-p1-moelle/meas_MID81_slaser_R_N=20+_1_longTE_SNR++++_FID41679.dat
# (INFO)  reco.py.__new__: read a (2, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (2, 8, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/314-yt-p1-moelle/20190925/01_0010_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/314-yt-p1-moelle/20190925/01_0009_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (1, 1, 4096) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID128_slaser_R_N=20+_1_longTE_SNR++++_FID39740.dat
# (INFO)  reco.py.__new__: read a (128, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID124_slaser_R_N=20+_1_longTE_SNR++++_FID39736.dat
# (INFO)  reco.py.__new__: read a (2, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (2, 8, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0020_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0018_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (1, 1, 4096) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 10:2 (REF with OVS)]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/349-ap-p1-moelle/meas_MID313_slaser_R_N=10_2_longTE_SNR+++_FID51947.dat
# (INFO)  reco.py.__new__: read a (96, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader.read_param_num: could not find parameter [lOffsetX]! :(
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 10:2 (REF with OVS)]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/349-ap-p1-moelle/meas_MID314_slaser_R_N=10_2_longTE_SNR+++_FID51948.dat
# (INFO)  reco.py.__new__: read a (8, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader.read_param_num: could not find parameter [lOffsetX]! :(
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (8, 8, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 10:2 (REF with OVS)]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/349-ap-p1-moelle/20200206/01_0006_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (WARNING) SIEMENS_data_file_reader.read_param_num: could not find parameter [lOffsetX]! :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 10:2 (REF with OVS)]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/349-ap-p1-moelle/20200206/01_0007_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (WARNING) SIEMENS_data_file_reader.read_param_num: could not find parameter [lOffsetX]! :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (1, 1, 4096) vector
# (INFO) ----------------------------------------
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading your job list...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: #0 phasing
# (INFO)  pipeline.run: #1 scaling intensity
# (INFO)  pipeline.run: #2 channel-combining
# (INFO)  pipeline.run: #3 zero-filling
# (INFO)  pipeline.run: #4 averaging
# (INFO)  pipeline.run: #5 apodizing
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: running job list...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#0 sLASER R:N=20:1 [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#0 sLASER R:N=20:1 [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#0 sLASER R:N=20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#0 sLASER R:N=20:1 [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#0 sLASER R:N=20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#0 sLASER R:N=20:1 [RAW]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#0 sLASER R:N=20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#0 sLASER R:N=20:1 [DCM]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#0 sLASER R:N=20:1 [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#0 sLASER R:N=20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#0 sLASER R:N=20:1 [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#0 sLASER R:N=20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#0 sLASER R:N=20:1 [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#0 sLASER R:N=20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#1 sLASER 20:1 [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#1 sLASER 20:1 [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#1 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#1 sLASER 20:1 [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#1 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#1 sLASER 20:1 [RAW]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#1 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#1 sLASER 20:1 [DCM]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#1 sLASER 20:1 [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#1 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#1 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#1 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#1 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#1 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#2 sLASER 20:1 [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#2 sLASER 20:1 [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#2 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#2 sLASER 20:1 [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#2 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#2 sLASER 20:1 [RAW]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#2 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#2 sLASER 20:1 [DCM]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#2 sLASER 20:1 [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#2 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#2 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#2 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#2 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#2 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#3 sLASER 20:1 [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#3 sLASER 20:1 [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#3 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#3 sLASER 20:1 [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#3 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#3 sLASER 20:1 [RAW]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#3 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#3 sLASER 20:1 [DCM]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#3 sLASER 20:1 [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#3 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#3 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#3 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#3 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#3 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#4 sLASER 10:2 (REF with OVS) [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#4 sLASER 10:2 (REF with OVS) [DCM]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-apodizing SNR of [#0 sLASER R:N=20:1 [RAW]] = 28.70
# (INFO)  pipeline._analyze: post-apodizing LW of [#0 sLASER R:N=20:1 [RAW]] = 25.02
# (INFO)  pipeline._analyze: post-apodizing SNR of [#0 sLASER R:N=20:1 [DCM]] = 27.13
# (INFO)  pipeline._analyze: post-apodizing LW of [#0 sLASER R:N=20:1 [DCM]] = 26.25
# (INFO)  pipeline._analyze: post-apodizing SNR of [#1 sLASER 20:1 [RAW]] = 31.14
# (INFO)  pipeline._analyze: post-apodizing LW of [#1 sLASER 20:1 [RAW]] = 28.69
# (INFO)  pipeline._analyze: post-apodizing SNR of [#1 sLASER 20:1 [DCM]] = 40.25
# (INFO)  pipeline._analyze: post-apodizing LW of [#1 sLASER 20:1 [DCM]] = 30.52
# (INFO)  pipeline._analyze: post-apodizing SNR of [#2 sLASER 20:1 [RAW]] = 62.82
# (INFO)  pipeline._analyze: post-apodizing LW of [#2 sLASER 20:1 [RAW]] = 19.53
# (INFO)  pipeline._analyze: post-apodizing SNR of [#2 sLASER 20:1 [DCM]] = 68.10
# (INFO)  pipeline._analyze: post-apodizing LW of [#2 sLASER 20:1 [DCM]] = 20.14
# (INFO)  pipeline._analyze: post-apodizing SNR of [#3 sLASER 20:1 [RAW]] = 49.01
# (INFO)  pipeline._analyze: post-apodizing LW of [#3 sLASER 20:1 [RAW]] = 21.36
# (INFO)  pipeline._analyze: post-apodizing SNR of [#3 sLASER 20:1 [DCM]] = 53.95
# (INFO)  pipeline._analyze: post-apodizing LW of [#3 sLASER 20:1 [DCM]] = 21.67
# (INFO)  pipeline._analyze: post-apodizing SNR of [#4 sLASER 10:2 (REF with OVS) [RAW]] = 30.43
# (INFO)  pipeline._analyze: post-apodizing LW of [#4 sLASER 10:2 (REF with OVS) [RAW]] = 31.74
# (INFO)  pipeline._analyze: post-apodizing SNR of [#4 sLASER 10:2 (REF with OVS) [DCM]] = 31.25
# (INFO)  pipeline._analyze: post-apodizing LW of [#4 sLASER 10:2 (REF with OVS) [DCM]] = 33.57
# (INFO)  pipeline.run: pipeline terminated!
# (INFO)  pipeline.run: returning processed signals!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#0 sLASER R:N=20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 25.02 Hz!
# <img src="data:image/png;base64,..." width="825">
# <img src="data:image/png;base64,..." width="825">
# (INFO)  MRSData2.analyze_snr_1d: results for [#0 sLASER R:N=20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 2.65E+03, N = 1.92E+02, SNR = 13.79!
# (INFO)  MRSData2.analyze_snr_1d: results for [#0 sLASER R:N=20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 1.77E+03, N = 1.92E+02, SNR = 9.20!
# (INFO)  MRSData2.analyze_snr_1d: results for [#0 sLASER R:N=20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 2.19E+03, N = 1.92E+02, SNR = 11.37!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#1 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 28.69 Hz!
# (INFO)  MRSData2.analyze_snr_1d: results for [#1 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 6.01E+03, N = 3.65E+02, SNR = 16.45!
# (INFO)  MRSData2.analyze_snr_1d: results for [#1 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 3.73E+03, N = 3.65E+02, SNR = 10.20!
# (INFO)  MRSData2.analyze_snr_1d: results for [#1 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 3.37E+03, N = 3.65E+02, SNR = 9.22!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#2 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 19.53 Hz!
# (INFO)  MRSData2.analyze_snr_1d: results for [#2 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 7.72E+03, N = 2.67E+02, SNR = 28.96!
# (INFO)  MRSData2.analyze_snr_1d: results for [#2 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 5.54E+03, N = 2.67E+02, SNR = 20.77!
# (INFO)  MRSData2.analyze_snr_1d: results for [#2 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 6.55E+03, N = 2.67E+02, SNR = 24.57!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#3 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 21.36 Hz!
# (INFO)  MRSData2.analyze_snr_1d: results for [#3 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 5.02E+03, N = 2.08E+02, SNR = 24.15!
# (INFO)  MRSData2.analyze_snr_1d: results for [#3 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 3.59E+03, N = 2.08E+02, SNR = 17.29!
# (INFO)  MRSData2.analyze_snr_1d: results for [#3 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 4.89E+03, N = 2.08E+02, SNR = 23.51!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#4 sLASER 10:2 (REF with OVS) [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 31.74 Hz!
# (INFO)  MRSData2.analyze_snr_1d: results for [#4 sLASER 10:2 (REF with OVS) [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 3.81E+03, N = 2.48E+02, SNR = 15.37!
# (INFO)  MRSData2.analyze_snr_1d: results for [#4 sLASER 10:2 (REF with OVS) [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 2.66E+03, N = 2.48E+02, SNR = 10.72!
# (INFO)  MRSData2.analyze_snr_1d: results for [#4 sLASER 10:2 (REF with OVS) [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 2.55E+03, N = 2.48E+02, SNR = 10.29!
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: checking datasets...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: dataset[0]:
# (INFO)  pipeline.run:   legend = sLASER R:N=20:1
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID157_slaser_R_N=20+_1_longTE_SNR++++_FID34191.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID155_slaser_R_N=20+_1_longTE_SNR++++_FID34189.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0016_slaser-r-n
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0015_slaser-r-n
# (INFO)  pipeline.run: dataset[1]:
# (INFO)  pipeline.run:   legend = sLASER 20:1
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID68_slaser_R_N=20+_1_longTE_SNR++++_FID41500.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID65_slaser_R_N=20+_1_longTE_SNR++++_FID41497.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/313-ft-p1-moelle/20190923/01_0011_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/313-ft-p1-moelle/20190923/01_0010_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  pipeline.run: dataset[2]:
# (INFO)  pipeline.run:   legend = sLASER 20:1
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/314-yt-p1-moelle/meas_MID83_slaser_R_N=20+_1_longTE_SNR++++_FID41681.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/314-yt-p1-moelle/meas_MID81_slaser_R_N=20+_1_longTE_SNR++++_FID41679.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/314-yt-p1-moelle/20190925/01_0010_slaser-r-n
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/314-yt-p1-moelle/20190925/01_0009_slaser-r-n
# (INFO)  pipeline.run: dataset[3]:
# (INFO)  pipeline.run:   legend = sLASER 20:1
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID128_slaser_R_N=20+_1_longTE_SNR++++_FID39740.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID124_slaser_R_N=20+_1_longTE_SNR++++_FID39736.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0020_slaser-r-n
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0018_slaser-r-n
# (INFO)  pipeline.run: dataset[4]:
# (INFO)  pipeline.run:   legend = sLASER 10:2 (REF with OVS)
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/349-ap-p1-moelle/meas_MID313_slaser_R_N=10_2_longTE_SNR+++_FID51947.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/349-ap-p1-moelle/meas_MID314_slaser_R_N=10_2_longTE_SNR+++_FID51948.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/349-ap-p1-moelle/20200206/01_0006_slaser-r-n/original-primary_e09_0001.dcm
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/349-ap-p1-moelle/20200206/01_0007_slaser-r-n/original-primary_e09_0001.dcm
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data files...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER R:N=20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID157_slaser_R_N=20+_1_longTE_SNR++++_FID34191.dat
# (INFO)  reco.py.__new__: read a (128, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER R:N=20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/296_ym_p1_brainmoelle/meas_MID155_slaser_R_N=20+_1_longTE_SNR++++_FID34189.dat
# (INFO)  reco.py.__new__: read a (2, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (2, 8, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER R:N=20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0016_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER R:N=20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/296_ym_p1_brainmoelle/296-ym-p1-brainmoelle/20190626/02_0015_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (1, 1, 4096) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID68_slaser_R_N=20+_1_longTE_SNR++++_FID41500.dat
# (INFO)  reco.py.__new__: read a (128, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/313-ft-p1-moelle/meas_MID65_slaser_R_N=20+_1_longTE_SNR++++_FID41497.dat
# (INFO)  reco.py.__new__: read a (2, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# ...
# (INFO)  pipeline._run_job: phasing on [#2 sLASER 20:1 [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#2 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#2 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#2 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#2 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_realign_2d: single-shot signal, cannot realign this!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#2 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#2 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#3 sLASER 20:1 [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#3 sLASER 20:1 [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#3 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#3 sLASER 20:1 [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#3 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#3 sLASER 20:1 [RAW]]...
# realigning: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#3 sLASER 20:1 [RAW]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#3 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#3 sLASER 20:1 [DCM]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#3 sLASER 20:1 [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#3 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#3 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#3 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#3 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_realign_2d: single-shot signal, cannot realign this!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#3 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#3 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#4 sLASER 10:2 (REF with OVS) [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# realigning: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#4 sLASER 10:2 (REF with OVS) [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#4 sLASER 10:2 (REF with OVS) [DCM]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (WARNING) MRSData2.correct_realign_2d: single-shot signal, cannot realign this!
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#4 sLASER 10:2 (REF with OVS) [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-apodizing SNR of [#0 sLASER R:N=20:1 [RAW]] = 28.70
# (INFO)  pipeline._analyze: post-apodizing LW of [#0 sLASER R:N=20:1 [RAW]] = 25.02
# (INFO)  pipeline._analyze: post-apodizing SNR of [#0 sLASER R:N=20:1 [DCM]] = 27.13
# (INFO)  pipeline._analyze: post-apodizing LW of [#0 sLASER R:N=20:1 [DCM]] = 26.25
# (INFO)  pipeline._analyze: post-apodizing SNR of [#1 sLASER 20:1 [RAW]] = 31.61
# (INFO)  pipeline._analyze: post-apodizing LW of [#1 sLASER 20:1 [RAW]] = 28.69
# (INFO)  pipeline._analyze: post-apodizing SNR of [#1 sLASER 20:1 [DCM]] = 40.25
# (INFO)  pipeline._analyze: post-apodizing LW of [#1 sLASER 20:1 [DCM]] = 30.52
# (INFO)  pipeline._analyze: post-apodizing SNR of [#2 sLASER 20:1 [RAW]] = 62.82
# (INFO)  pipeline._analyze: post-apodizing LW of [#2 sLASER 20:1 [RAW]] = 19.53
# (INFO)  pipeline._analyze: post-apodizing SNR of [#2 sLASER 20:1 [DCM]] = 68.10
# (INFO)  pipeline._analyze: post-apodizing LW of [#2 sLASER 20:1 [DCM]] = 20.14
# (INFO)  pipeline._analyze: post-apodizing SNR of [#3 sLASER 20:1 [RAW]] = 49.01
# (INFO)  pipeline._analyze: post-apodizing LW of [#3 sLASER 20:1 [RAW]] = 21.36
# (INFO)  pipeline._analyze: post-apodizing SNR of [#3 sLASER 20:1 [DCM]] = 53.95
# (INFO)  pipeline._analyze: post-apodizing LW of [#3 sLASER 20:1 [DCM]] = 21.67
# (INFO)  pipeline._analyze: post-apodizing SNR of [#4 sLASER 10:2 (REF with OVS) [RAW]] = 27.42
# (INFO)  pipeline._analyze: post-apodizing LW of [#4 sLASER 10:2 (REF with OVS) [RAW]] = 34.18
# (INFO)  pipeline._analyze: post-apodizing SNR of [#4 sLASER 10:2 (REF with OVS) [DCM]] = 31.25
# (INFO)  pipeline._analyze: post-apodizing LW of [#4 sLASER 10:2 (REF with OVS) [DCM]] = 33.57
# (INFO)  pipeline.run: pipeline terminated!
# (INFO)  pipeline.run: returning processed signals!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#0 sLASER R:N=20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 25.02 Hz!
# (INFO)  MRSData2.analyze_snr_1d: results for [#0 sLASER R:N=20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 2.65E+03, N = 1.92E+02, SNR = 13.79!
# (INFO)  MRSData2.analyze_snr_1d: results for [#0 sLASER R:N=20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 1.77E+03, N = 1.92E+02, SNR = 9.20!
# (INFO)  MRSData2.analyze_snr_1d: results for [#0 sLASER R:N=20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 2.19E+03, N = 1.92E+02, SNR = 11.37!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#1 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 28.69 Hz!
# (INFO)  MRSData2.analyze_snr_1d: results for [#1 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 5.96E+03, N = 3.55E+02, SNR = 16.78!
# (INFO)  MRSData2.analyze_snr_1d: results for [#1 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 3.57E+03, N = 3.55E+02, SNR = 10.06!
# (INFO)  MRSData2.analyze_snr_1d: results for [#1 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 3.41E+03, N = 3.55E+02, SNR = 9.62!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#2 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 19.53 Hz!
# (INFO)  MRSData2.analyze_snr_1d: results for [#2 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 7.72E+03, N = 2.67E+02, SNR = 28.96!
# (INFO)  MRSData2.analyze_snr_1d: results for [#2 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 5.54E+03, N = 2.67E+02, SNR = 20.77!
# (INFO)  MRSData2.analyze_snr_1d: results for [#2 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 6.55E+03, N = 2.67E+02, SNR = 24.57!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#3 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 21.36 Hz!
# (INFO)  MRSData2.analyze_snr_1d: results for [#3 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 5.02E+03, N = 2.08E+02, SNR = 24.15!
# (INFO)  MRSData2.analyze_snr_1d: results for [#3 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 3.59E+03, N = 2.08E+02, SNR = 17.29!
# (INFO)  MRSData2.analyze_snr_1d: results for [#3 sLASER 20:1 [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 4.89E+03, N = 2.08E+02, SNR = 23.51!
# (INFO)  MRSData2.analyze_linewidth_1d: results for [#4 sLASER 10:2 (REF with OVS) [RAW]] coming...
# (INFO)  MRSData2.analyze_linewidth_1d: LW = 34.18 Hz!
# (INFO)  MRSData2.analyze_snr_1d: results for [#4 sLASER 10:2 (REF with OVS) [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 3.85E+03, N = 2.80E+02, SNR = 13.76!
# (INFO)  MRSData2.analyze_snr_1d: results for [#4 sLASER 10:2 (REF with OVS) [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 2.50E+03, N = 2.80E+02, SNR = 8.93!
# (INFO)  MRSData2.analyze_snr_1d: results for [#4 sLASER 10:2 (REF with OVS) [RAW]] coming...
# (INFO)  MRSData2.analyze_snr_1d: S = 2.67E+03, N = 2.80E+02, SNR = 9.54!

# %% [markdown]
# ### Analyze optimization results

# %%
plt.close('all')

df = pd.read_pickle("./notebooks/optim_data_realigning_results.pkl")

df["p"] = df["moving_averages"].astype(str) + "_" + df["inter_corr_mode"].astype(str) + "_" +  df["freq_shift_max"].astype(str) + "_" + df["allowed_apodization"].astype(str)

patient_list = df["patient"].unique()
df["NAA_s_rel"] = 0
df["Cre_s_rel"] = 0
df["Cho_s_rel"] = 0
df["NAA_snr_rel"] = 0
df["Cre_snr_rel"] = 0
df["Cho_snr_rel"] = 0
df["lw_rel"] = 0

for p in patient_list:
    df_min = df.loc[(df["patient"] == p) & (df["moving_averages"] == 0)]

    df.at[df["patient"] == p, "NAA_s_rel"] = (df.loc[df["patient"] == p]["NAA_s"] - df_min["NAA_s"].min())/ df_min["NAA_s"].min() * 100.0
    df.at[df["patient"] == p, "Cre_s_rel"] = (df.loc[df["patient"] == p]["Cre_s"] - df_min["Cre_s"].min())/ df_min["Cre_s"].min() * 100.0
    df.at[df["patient"] == p, "Cho_s_rel"] = (df.loc[df["patient"] == p]["Cho_s"] - df_min["Cho_s"].min())/ df_min["Cho_s"].min() * 100.0

    df.at[df["patient"] == p, "NAA_snr_rel"] = (df.loc[df["patient"] == p]["NAA_snr"] - df_min["NAA_snr"].min())/ df_min["NAA_snr"].min() * 100.0
    df.at[df["patient"] == p, "Cre_snr_rel"] = (df.loc[df["patient"] == p]["Cre_snr"] - df_min["Cre_snr"].min())/ df_min["Cre_snr"].min() * 100.0
    df.at[df["patient"] == p, "Cho_snr_rel"] = (df.loc[df["patient"] == p]["Cho_snr"] - df_min["Cho_snr"].min())/ df_min["Cho_snr"].min() * 100.0

    df.at[df["patient"] == p, "lw_rel"] = df.loc[df["patient"] == p]["lw"] - df_min["lw"].min()


df["met_s_rel"] = df[["NAA_s_rel", "Cre_s_rel", "Cho_s_rel"]].max(axis=1)
df["met_snr_rel"] = df[["NAA_snr_rel", "Cre_snr_rel", "Cho_snr_rel"]].max(axis=1)

fig = plt.figure()
ax = fig.subplots(2, 1, sharex=True)
sns.lineplot(data=df, x="p", y="met_s_rel", hue="patient", ax=ax[0], legend=False)
ax[0].grid('on')
sns.lineplot(data=df, x="p", y="lw_rel", hue="patient", ax=ax[1], legend='brief')
ax[1].grid('on')
# Out:
# <img src="data:image/png;base64,..." width="825">

# %% [markdown]
# We clearly see the 7 parts of the optimization:
# 1. no realigning, that's our reference
# 2. moving_average=1, peak pick
# 3. moving_average=1, corr mode
# 4. moving_average=1, peak pick
# 5. moving_average=1, corr mode
# 6. moving_average=1, peak pick
# 7. moving_average=1, corr mode
#
# First let's remove part 3, 5, 7 (corr mode) which has high LW, not acceptable

# %%
df = df.loc[df["inter_corr_mode"] == False]

fig = plt.figure()
ax = fig.subplots(2, 1, sharex=True)
sns.lineplot(data=df, x="p", y="met_s_rel", hue="patient", ax=ax[0], legend=False)
ax[0].grid('on')
sns.lineplot(data=df, x="p", y="lw_rel", hue="patient", ax=ax[1], legend='brief')
ax[1].grid('on')
# Out:
# <img src="data:image/png;base64,..." width="825">

# %% [markdown]
# * moving_averages=1 gives the lowest LW
# * and most of the time, the best SNR

# %%
df = df.loc[df["moving_averages"] < 2]

fig = plt.figure()
ax = fig.subplots(2, 1, sharex=True)
sns.lineplot(data=df, x="p", y="met_s_rel", hue="patient", ax=ax[0], legend=False)
ax[0].grid('on')
sns.lineplot(data=df, x="p", y="lw_rel", hue="patient", ax=ax[1], legend='brief')
ax[1].grid('on')
# Out:
# <img src="data:image/png;base64,..." width="825">

# %% [markdown]
# * A max frequency shift of 50Hz looks enough
# * Going for 100Hz makes it unstable

# %%
df = df.loc[df["freq_shift_max"] == 50]

fig = plt.figure()
ax = fig.subplots(2, 1, sharex=True)
sns.lineplot(data=df, x="p", y="met_s_rel", hue="patient", ax=ax[0], legend=False)
ax[0].grid('on')
sns.lineplot(data=df, x="p", y="lw_rel", hue="patient", ax=ax[1], legend='brief')
ax[1].grid('on')
# Out:
# <img src="data:image/png;base64,..." width="825">

# %% [markdown]
# An apodization of 5Hz is actually helping the realignment :)

# %%
fig = plt.figure()
ax = fig.subplots(4, 1, sharex=True)
sns.lineplot(data=df, x="p", y="NAA_s_rel", hue="patient", ax=ax[0], legend=False)
ax[0].grid('on')
sns.lineplot(data=df, x="p", y="Cre_s_rel", hue="patient", ax=ax[1], legend=False)
ax[1].grid('on')
sns.lineplot(data=df, x="p", y="Cho_s_rel", hue="patient", ax=ax[2], legend=False)
ax[2].grid('on')
sns.lineplot(data=df, x="p", y="lw_rel", hue="patient", ax=ax[3], legend='brief')
ax[3].grid('on')
# Out:
# <img src="data:image/png;base64,..." width="825">

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Mmmh okay. To conclude, the best way to realign is:
# * 5Hz apodization, no moving averages
# * Probalby 50Hz max shift allowed

# %% [markdown]
# Apodization differs a bit from what we found for data discarding... Strange.
