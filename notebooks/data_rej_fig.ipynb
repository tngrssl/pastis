# %%
# %% init
import os
os.chdir("/home/tangir/crmbm/python/pastis")

from IPython import get_ipython
get_ipython().magic("clear")

import matplotlib.pylab as plt
import mrs.reco as reco
import mrs.log as log
import numpy as np

plt.close("all")
plt.rcParams['figure.dpi'] = 75
plt.rcParams['figure.max_open_warning'] = 1000
plt.rcParams["figure.figsize"] = [8, 6]
# get_ipython().magic("matplotlib inline")
get_ipython().magic("matplotlib notebook")
log.setLevel(log.INFO)
# Out:
# (DEBUG) Loaded backend nbAgg version unknown.

# %% [markdown]
# # Classic example of data rejection
# 08/11/2019 - 329-pi-p1-moelle - Pujalina :)

# %%
p = reco.pipeline("sc_std_nows")

p.dataset[0]["legend"] = "sLASER 20:1"
p.dataset[0]["resp_bpm"] = 16
p.dataset[0]["heart_bpm"] = 55
p.dataset[0]["dcm"]["files"] = ["/home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0020_slaser-r-n",
                                "/home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0018_slaser-r-n"]
p.dataset[0]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID128_slaser_R_N=20+_1_longTE_SNR++++_FID39740.dat",
                                "/home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID124_slaser_R_N=20+_1_longTE_SNR++++_FID39736.dat"]

p.settings["display"] = True
p.run()
# Out:
# (INFO)  pipeline.load_template: load pipeline from template file [sc_std_nows.pkl]...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: checking datasets...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: dataset[0]:
# (INFO)  pipeline.run:   legend = sLASER 20:1
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID128_slaser_R_N=20+_1_longTE_SNR++++_FID39740.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID124_slaser_R_N=20+_1_longTE_SNR++++_FID39736.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0020_slaser-r-n
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0018_slaser-r-n
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data files...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID128_slaser_R_N=20+_1_longTE_SNR++++_FID39740.dat
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 48
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 34
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 39
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 37
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 38
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 43
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 41
#   match = re.findall(rgx, header_string)
# (INFO)  reco.py.__new__: read a (128, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID124_slaser_R_N=20+_1_longTE_SNR++++_FID39736.dat
# (INFO)  reco.py.__new__: read a (2, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  pipeline.run: got a (2, 8, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0020_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 20:1]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0018_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  pipeline.run: got a (1, 1, 4096) vector
# (INFO) ----------------------------------------
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading your job list...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: #0 phasing
# (INFO)  pipeline.run: #1 scaling intensity
# (INFO)  pipeline.run: #2 channel-combining
# (INFO)  pipeline.run: #3 estimating noise level
# (INFO)  pipeline.run: #4 zero-filling
# (INFO)  pipeline.run: #5 apodizing
# (INFO)  pipeline.run: #6 frequency realigning
# (INFO)  pipeline.run: #7 data rejecting
# (INFO)  pipeline.run: #8 averaging
# (INFO)  pipeline.run: #9 frequency shifting
# (INFO)  pipeline.run: #10 cropping
# (INFO)  pipeline.run: #11 displaying
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: running job list...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#0 sLASER 20:1 [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#0 sLASER 20:1 [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (INFO)  pipeline._analyze: post-phasing SNR of [#0 sLASER 20:1 [RAW]] = 9.83
# (INFO)  pipeline._analyze: post-phasing LW of [#0 sLASER 20:1 [RAW]] = 19.53
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#0 sLASER 20:1 [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-scaling intensity SNR of [#0 sLASER 20:1 [RAW]] = 9.83
# (INFO)  pipeline._analyze: post-scaling intensity LW of [#0 sLASER 20:1 [RAW]] = 19.53
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#0 sLASER 20:1 [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-channel-combining SNR of [#0 sLASER 20:1 [RAW]] = 9.83
# (INFO)  pipeline._analyze: post-channel-combining LW of [#0 sLASER 20:1 [RAW]] = 19.53
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: estimating noise level on [#0 sLASER 20:1 [RAW]]...
# (INFO)  MRSData2.analyze_noise_nd: noise level = 6.05E+00
# (INFO)  MRSData2.analyze_noise_nd: noise level = 4.94E+01
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-estimating noise level SNR of [#0 sLASER 20:1 [RAW]] = 9.83
# (INFO)  pipeline._analyze: post-estimating noise level LW of [#0 sLASER 20:1 [RAW]] = 19.53
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#0 sLASER 20:1 [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-zero-filling SNR of [#0 sLASER 20:1 [RAW]] = 9.83
# (INFO)  pipeline._analyze: post-zero-filling LW of [#0 sLASER 20:1 [RAW]] = 19.53
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#0 sLASER 20:1 [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-apodizing SNR of [#0 sLASER 20:1 [RAW]] = 22.42
# (INFO)  pipeline._analyze: post-apodizing LW of [#0 sLASER 20:1 [RAW]] = 21.97
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#0 sLASER 20:1 [RAW]]...
# realigning: ██████████████████████████████ done.
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency realigning SNR of [#0 sLASER 20:1 [RAW]] = 27.33
# (INFO)  pipeline._analyze: post-frequency realigning LW of [#0 sLASER 20:1 [RAW]] = 18.31
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: data rejecting on [#0 sLASER 20:1 [RAW]]...
# (INFO)  MRSData2.correct_analyze_and_reject_2d: This is the 1st time we perform data rejection on this signal!
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Pre-data-rejection SNR = 306.29
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Pre-data-rejection linewidth = 18.92 Hz
# analyzing: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: peak analysis: means ± std. deviations
# (INFO)  MRSData2.correct_analyze_and_reject_2d: rel. peak amplitude = 0.00 ± 60.18 %
# (INFO)  MRSData2.correct_analyze_and_reject_2d: abs. linewidth = 24.0 ± 19.8 Hz (0.081 ± 0.067 ppm)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: abs. frequency = 4.68 ± 0.01 ppm (± 4.4 Hz)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: abs. phase = -0.67 ± 0.72 rad
# adjusting rejection threshold for [amplitude (%)]: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: could not improve SNR above threshold but will reduce peak linewidth! :)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: optimal [amplitude (%)] = 143.9
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [amplitude (%)] SNR = 311.61
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [amplitude (%)] linewidth = 18.31 Hz
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# adjusting rejection threshold for [linewidth (Hz)]: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: SNR change above threshold: 7.22% > 1.00% threshold! :)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: optimal [linewidth (Hz)] = 39.8
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [linewidth (Hz)] SNR = 334.10
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [linewidth (Hz)] linewidth = 17.09 Hz
# adjusting rejection threshold for [chemical shift (ppm)]: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: could not improve SNR above threshold but will reduce peak linewidth! :)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: optimal [chemical shift (ppm)] = 0.0
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [chemical shift (ppm)] SNR = 311.61
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [chemical shift (ppm)] linewidth = 18.31 Hz
# adjusting rejection threshold for [phase std. factor (%)]: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: could not improve SNR above threshold but will reduce peak linewidth! :)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: optimal [phase std. factor (%)] = 1.6
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [phase std. factor (%)] SNR = 311.61
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [phase std. factor (%)] linewidth = 18.31 Hz
# (INFO)  MRSData2.correct_analyze_and_reject_2d: best adjustment done with data_rejection_method.AUTO_LINEWIDTH regarding SNR! (round #1)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection SNR = 334.10
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection linewidth = 17.09 Hz
# rejecting data: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: data rejection: summary (round #1)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: number of averages rejected because of...
# (INFO)  MRSData2.correct_analyze_and_reject_2d: amplitude = 0
# (INFO)  MRSData2.correct_analyze_and_reject_2d: linewidth = 23
# (INFO)  MRSData2.correct_analyze_and_reject_2d: frequency = 0
# (INFO)  MRSData2.correct_analyze_and_reject_2d: phase = 0
# realigning: █████████████████████████████ done.
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO)  MRSData2.correct_analyze_and_reject_2d: TOTAL data rejection = 23 / 128 (18%)
# analyzing: ██████████████████████████████ done.
# <img src="data:image/png;base64,..." width="1000">
# realigning: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# realigning: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# <img src="data:image/png;base64,..." width="640">
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Final post-data-rejection SNR = 334.10
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Final post-data-rejection linewidth = 17.09 Hz
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-data rejecting SNR of [#0 sLASER 20:1 [RAW]] = 27.04
# (INFO)  pipeline._analyze: post-data rejecting LW of [#0 sLASER 20:1 [RAW]] = 17.09
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#0 sLASER 20:1 [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-averaging SNR of [#0 sLASER 20:1 [RAW]] = 27.04
# (INFO)  pipeline._analyze: post-averaging LW of [#0 sLASER 20:1 [RAW]] = 17.09
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency shifting on [#0 sLASER 20:1 [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency shifting SNR of [#0 sLASER 20:1 [RAW]] = 27.04
# (INFO)  pipeline._analyze: post-frequency shifting LW of [#0 sLASER 20:1 [RAW]] = 17.09
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: cropping on [#0 sLASER 20:1 [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-cropping SNR of [#0 sLASER 20:1 [RAW]] = 26.09
# (INFO)  pipeline._analyze: post-cropping LW of [#0 sLASER 20:1 [RAW]] = 16.28
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: displaying on [#0 sLASER 20:1 [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#0 sLASER 20:1 [DCM]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#0 sLASER 20:1 [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-phasing SNR of [#0 sLASER 20:1 [DCM]] = 11.97
# (INFO)  pipeline._analyze: post-phasing LW of [#0 sLASER 20:1 [DCM]] = 17.70
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#0 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-scaling intensity SNR of [#0 sLASER 20:1 [DCM]] = 11.97
# (INFO)  pipeline._analyze: post-scaling intensity LW of [#0 sLASER 20:1 [DCM]] = 17.70
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#0 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-channel-combining SNR of [#0 sLASER 20:1 [DCM]] = 11.97
# (INFO)  pipeline._analyze: post-channel-combining LW of [#0 sLASER 20:1 [DCM]] = 17.70
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: estimating noise level on [#0 sLASER 20:1 [DCM]]...
# (INFO)  MRSData2.analyze_noise_nd: noise level = 7.18E+00
# (INFO)  MRSData2.analyze_noise_nd: noise level = 4.95E+02
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-estimating noise level SNR of [#0 sLASER 20:1 [DCM]] = 11.97
# (INFO)  pipeline._analyze: post-estimating noise level LW of [#0 sLASER 20:1 [DCM]] = 17.70
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#0 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-zero-filling SNR of [#0 sLASER 20:1 [DCM]] = 11.97
# (INFO)  pipeline._analyze: post-zero-filling LW of [#0 sLASER 20:1 [DCM]] = 17.70
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: apodizing on [#0 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-apodizing SNR of [#0 sLASER 20:1 [DCM]] = 30.16
# (INFO)  pipeline._analyze: post-apodizing LW of [#0 sLASER 20:1 [DCM]] = 18.92
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#0 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_realign_2d: single-shot signal, cannot realign this!
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency realigning SNR of [#0 sLASER 20:1 [DCM]] = 30.16
# (INFO)  pipeline._analyze: post-frequency realigning LW of [#0 sLASER 20:1 [DCM]] = 18.92
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: data rejecting on [#0 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_analyze_and_reject_2d: single-shot signal, nothing to analyze!
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-data rejecting SNR of [#0 sLASER 20:1 [DCM]] = 30.16
# (INFO)  pipeline._analyze: post-data rejecting LW of [#0 sLASER 20:1 [DCM]] = 18.92
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#0 sLASER 20:1 [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-averaging SNR of [#0 sLASER 20:1 [DCM]] = 30.16
# (INFO)  pipeline._analyze: post-averaging LW of [#0 sLASER 20:1 [DCM]] = 18.92
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency shifting on [#0 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency shifting SNR of [#0 sLASER 20:1 [DCM]] = 30.16
# (INFO)  pipeline._analyze: post-frequency shifting LW of [#0 sLASER 20:1 [DCM]] = 18.92
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: cropping on [#0 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-cropping SNR of [#0 sLASER 20:1 [DCM]] = 29.75
# (INFO)  pipeline._analyze: post-cropping LW of [#0 sLASER 20:1 [DCM]] = 19.53
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: displaying on [#0 sLASER 20:1 [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-displaying SNR of [#0 sLASER 20:1 [RAW]] = 26.09
# (INFO)  pipeline._analyze: post-displaying LW of [#0 sLASER 20:1 [RAW]] = 16.28
# (INFO)  pipeline._analyze: post-displaying SNR of [#0 sLASER 20:1 [DCM]] = 29.75
# (INFO)  pipeline._analyze: post-displaying LW of [#0 sLASER 20:1 [DCM]] = 19.53
# (INFO)  pipeline.display_analyze_results: displaying SNR and linewidth final results...
# (INFO)  pipeline.get_analyze_results: converting analyze results to arrays...
# (INFO) ----------------------------------------
# RAW / DCM dataset 	SNR (u.a)           	LW (Hz)             	ref. data LW (Hz)
#
# #0 sLASER 20:1	26.09 / 29.75       	16.28 / 19.53       	26.04 / 19.53
# (INFO) ----------------------------------------
# <img src="data:image/png;base64,..." width="640">
# (INFO)  pipeline.run: pipeline terminated!
# (INFO)  pipeline.run: returning processed signals!
# [{'legend': '#0 sLASER 20:1',
#   'raw': {'files': ['/home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID128_slaser_R_N=20+_1_longTE_SNR++++_FID39740.dat',
#     '/home/tangir/crmbm/acq_twix/311-sl-p1-moelle/meas_MID124_slaser_R_N=20+_1_longTE_SNR++++_FID39736.dat'],
#    'data': MRSData2([ 4.54604815e+02-114.46837807j,  4.72322244e+02 -47.98671573j,
#               4.38878397e+02 +33.14445392j, ...,
#              -2.75030351e-01  +0.57490861j, -6.30959158e-01  +0.20156784j,
#              -3.43646709e-01  +0.23688037j]),
#    'analysis-results': {'phasing': {'snr': 9.826557379485902,
#      'lw': 19.531250000000252},
#     'scaling intensity': {'snr': 9.826557379485905, 'lw': 19.531250000000252},
#     'channel-combining': {'snr': 9.826557379485905, 'lw': 19.531250000000252},
#     'estimating noise level': {'snr': 9.826557379485905,
#      'lw': 19.531250000000252},
#     'zero-filling': {'snr': 9.826557379485905, 'lw': 19.531250000000252},
#     'apodizing': {'snr': 22.422275229847045, 'lw': 21.972656250000018},
#     'frequency realigning': {'snr': 27.33375102168719,
#      'lw': 18.31054687500037},
#     'data rejecting': {'snr': 27.040021822681414, 'lw': 17.089843749999428},
#     'averaging': {'snr': 27.040021822681414, 'lw': 17.089843749999428},
#     'frequency shifting': {'snr': 27.040021822681414,
#      'lw': 17.089843749999428},
#     'cropping': {'snr': 26.090640922407065, 'lw': 16.276041666666174}},
#    'ref-data-analysis-results': {'snr': 7388.567843269976,
#     'lw': 26.0416666666663}},
#   'dcm': {'files': ['/home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0020_slaser-r-n',
#     '/home/tangir/crmbm/acq/311-sl-p1-moelle/20190905/01_0018_slaser-r-n'],
#    'data': MRSData2([668.93261719 +63.46289444j, 545.05794802+261.91233138j,
#              326.82433024+208.81345923j, ...,  -0.          +0.j        ,
#               -0.          +0.j        ,  -0.          +0.j        ]),
#    'analysis-results': {'phasing': {'snr': 11.968979521452127,
#      'lw': 17.700195312499897},
#     'scaling intensity': {'snr': 11.968979521452127, 'lw': 17.700195312499897},
#     'channel-combining': {'snr': 11.968979521452127, 'lw': 17.700195312499897},
#     'estimating noise level': {'snr': 11.968979521452127,
#      'lw': 17.700195312499897},
#     'zero-filling': {'snr': 11.968979521452127, 'lw': 17.700195312499897},
#     'apodizing': {'snr': 30.157359176409912, 'lw': 18.920898437499783},
#     'frequency realigning': {'snr': 30.157359176409912,
#      'lw': 18.920898437499783},
#     'data rejecting': {'snr': 30.157359176409912, 'lw': 18.920898437499783},
#     'averaging': {'snr': 30.157359176409912, 'lw': 18.920898437499783},
#     'frequency shifting': {'snr': 30.157359176409912,
#      'lw': 18.920898437499783},
#     'cropping': {'snr': 29.74797025074895, 'lw': 19.531250000000252}},
#    'ref-data-analysis-results': {'snr': 7232.275145067674,
#     'lw': 19.531249999999723}},
#   'physio-file': None,
#   'imaging-file': None,
#   'resp_bpm': 16,
#   'heart_bpm': 55,
#   'comment': None}]

# %%
fig = plt.figure(162)
fig.set_size_inches(10, 6)
fig.suptitle("")
fig.axes[0].set_title("Amplitude change")
fig.axes[0].set_ylabel("Amplitude relative change (%)")
fig.axes[1].set_title("FWHM linewidth change")
fig.axes[1].set_ylabel("FWHM linewidth (Hz)")
fig.axes[2].set_title("Chemical shift change")
fig.axes[2].set_ylabel("Chemical shift relative change (ppm)")
fig.axes[2].set_xlabel("Acquisition time (s)")
fig.axes[3].set_title("Phase change")
fig.axes[3].set_ylabel("Phase relative change (rd)")
fig.axes[3].set_xlabel("Acquisition time (s)")

fig.axes[4].set_ylabel("Individual acquired spectrum index")
fig.axes[4].set_xlabel("Chemical shift (ppm)")
# Out:
# Text(0.5, 23.52222222222222, 'Chemical shift (ppm)')

# %%
tmp_fig = plt.figure(132000)
tmpax = tmp_fig.subplots()
lll = tmpax.plot([0, 1], [0, 1], 'green', [0, 1], [0, 1], 'red', [0, 1])

fig.axes[4].legend(lll, ["Accepted", "Rejected"], bbox_to_anchor=(0, 1, 1., .102), loc=3, ncol=2)
fig.tight_layout()

# annotations...
props = dict(boxstyle='square', facecolor='white', alpha=0.9, edgecolor='grey')

xlim = fig.axes[0].get_xlim()
ylim = fig.axes[0].get_ylim()
fig.axes[0].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.06, 
                     "A.",
                     fontsize=12,
                     bbox=props)

xlim = fig.axes[1].get_xlim()
ylim = fig.axes[1].get_ylim()
fig.axes[1].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.06, 
                     "B.",
                     fontsize=12,
                     bbox=props)

xlim = fig.axes[2].get_xlim()
ylim = fig.axes[2].get_ylim()
fig.axes[2].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.06, 
                     "C.",
                     fontsize=12,
                     bbox=props)

xlim = fig.axes[3].get_xlim()
ylim = fig.axes[3].get_ylim()
fig.axes[3].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.06, 
                     "D.",
                     fontsize=12,
                     bbox=props)

xlim = fig.axes[4].get_xlim()
ylim = fig.axes[4].get_ylim()
fig.axes[4].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.04, 
                     "E.",
                     fontsize=12,
                     bbox=props)

fig.savefig("./notebooks/figs/fig_data_rej.svg")
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # Data rejection of motion data
# 25/09/2020 - 349-ap-p2-moelle - Admah Fajar P2
# TWIX data was broken... but ok using matlab's mapvbvd

# %%
import scipy.io
plt.close("all")

s = reco.MRSData2("/home/tangir/crmbm/acq_twix/349-ap-p2-moelle/meas_MID102_slaser_R_N=10_2_longTE_SNR+++_FID63232.dat")
mat = scipy.io.loadmat("/home/tangir/crmbm/acq_twix/349-ap-p2-moelle/fids.mat")
data_from_mat = np.squeeze(mat["ttt"][:, :, 0, 0, 0, 0, 0, 0, 0, :])
data_from_mat = np.transpose(data_from_mat, (2, 1, 0))
s[:] = data_from_mat[:, :, 0:8192]

s_ref = reco.MRSData2("/home/tangir/crmbm/acq_twix/349-ap-p2-moelle/meas_MID101_slaser_R_N=10_2_longTE_SNR+++_FID63231.dat")

s._data_ref = s_ref
s._display_label = ""

#s = s.correct_phase_3d()
s = s.correct_intensity_scaling_nd()
s = s.correct_combine_channels_3d(False)
s = s.correct_zerofill_nd(display=True)
s = s.correct_apodization_nd(15, True)
#s = s.correct_realign_2d([4.5, 5], 4)
s = s.correct_analyze_and_reject_2d([4.5, 5], 2,
                                    {"amplitude (%)": None, 
                                     "linewidth (Hz)": None, 
                                     "chemical shift (ppm)": None, 
                                     "phase std. factor (%)": None}, True, [reco.data_rejection_method.AUTO_AMPLITUDE,
                                                reco.data_rejection_method.AUTO_LINEWIDTH,
                                                reco.data_rejection_method.AUTO_FREQUENCY,
                                                reco.data_rejection_method.AUTO_PHASE], 0.0,
                                    True, [1, 6])
# Out:
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/349-ap-p2-moelle/meas_MID102_slaser_R_N=10_2_longTE_SNR+++_FID63232.dat
# Scan 1/1, read all mdhs:   0%|          | 0.00/52.3M [00:00<?, ?B/s]/home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/mapvbvd/mapVBVD.py:89: UserWarning:
# An unexpected read error occurred at this byte offset: 54822528 (0.05105745792388916 GiB)
# Will stop reading now.
#
#   warnings.warn(warningString)
# Scan 1/1, read all mdhs:  99%|█████████▉| 51.8M/52.3M [00:00<00:00, 2.12GB/s]
# read data:   0%|          | 0/1 [00:00<?, ?it/s]
# pymapVBVD version 0.4.1
# Software version: VB
# (INFO)  reco.py.__new__: read a (97, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/349-ap-p2-moelle/meas_MID101_slaser_R_N=10_2_longTE_SNR+++_FID63231.dat
# (INFO)  reco.py.__new__: read a (8, 8, 8192) vector
# (WARNING) SIEMENS_data_file_reader._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (INFO)  MRSData2.correct_analyze_and_reject_2d: This is the 1st time we perform data rejection on this signal!
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Pre-data-rejection SNR = 113.18
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Pre-data-rejection linewidth = 24.72 Hz
# analyzing: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: peak analysis: means ± std. deviations
# (INFO)  MRSData2.correct_analyze_and_reject_2d: rel. peak amplitude = -0.00 ± 41.47 %
# (INFO)  MRSData2.correct_analyze_and_reject_2d: abs. linewidth = 20.1 ± 13.0 Hz (0.068 ± 0.044 ppm)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: abs. frequency = 4.69 ± 0.03 ppm (± 10.0 Hz)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: abs. phase = -0.60 ± 0.45 rad
# adjusting rejection threshold for [amplitude (%)]: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: could not improve SNR above threshold but will reduce peak linewidth! :)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: optimal [amplitude (%)] = 80.5
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [amplitude (%)] SNR = 110.48
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [amplitude (%)] linewidth = 36.93 Hz
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# adjusting rejection threshold for [linewidth (Hz)]: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: SNR change above threshold: 6.82% > 0.00% threshold! :)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: optimal [linewidth (Hz)] = 17.2
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [linewidth (Hz)] SNR = 118.02
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [linewidth (Hz)] linewidth = 20.14 Hz
# adjusting rejection threshold for [chemical shift (ppm)]: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: SNR change above threshold: 0.01% > 0.00% threshold! :)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: optimal [chemical shift (ppm)] = 0.0
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [chemical shift (ppm)] SNR = 110.49
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [chemical shift (ppm)] linewidth = 25.33 Hz
# adjusting rejection threshold for [phase std. factor (%)]: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: could not improve SNR above threshold but will reduce peak linewidth! :)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: optimal [phase std. factor (%)] = 0.9
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [phase std. factor (%)] SNR = 110.48
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection based on [phase std. factor (%)] linewidth = 36.93 Hz
# (INFO)  MRSData2.correct_analyze_and_reject_2d: best adjustment done with data_rejection_method.AUTO_LINEWIDTH regarding SNR! (round #1)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection SNR = 118.02
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Post-data-rejection linewidth = 20.14 Hz
# rejecting data: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: data rejection: summary (round #1)
# (INFO)  MRSData2.correct_analyze_and_reject_2d: number of averages rejected because of...
# (INFO)  MRSData2.correct_analyze_and_reject_2d: amplitude = 0
# (INFO)  MRSData2.correct_analyze_and_reject_2d: linewidth = 41
# (INFO)  MRSData2.correct_analyze_and_reject_2d: frequency = 0
# (INFO)  MRSData2.correct_analyze_and_reject_2d: phase = 0
# realigning: ██████████████████████████████ done.
# (INFO)  MRSData2.correct_analyze_and_reject_2d: TOTAL data rejection = 41 / 97 (42%)
# analyzing: ██████████████████████████████ done.
# <img src="data:image/png;base64,..." width="1000">
# realigning: ██████████████████████████████ done.
# realigning: ██████████████████████████████ done.
# <img src="data:image/png;base64,..." width="640">
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Final post-data-rejection SNR = 118.02
# (INFO)  MRSData2.correct_analyze_and_reject_2d: * Final post-data-rejection linewidth = 20.14 Hz

# %%
fig = plt.figure(162)
fig.set_size_inches(10, 6)
fig.suptitle("")
fig.axes[0].set_title("Amplitude change")
fig.axes[0].set_ylabel("Amplitude relative change (%)")
fig.axes[1].set_title("FWHM linewidth change")
fig.axes[1].set_ylabel("FWHM linewidth (Hz)")
fig.axes[2].set_title("Chemical shift change")
fig.axes[2].set_ylabel("Chemical shift relative change (ppm)")
fig.axes[2].set_xlabel("Acquisition time (s)")
fig.axes[3].set_title("Phase change")
fig.axes[3].set_ylabel("Phase relative change (rd)")
fig.axes[3].set_xlabel("Acquisition time (s)")

fig.axes[4].set_ylabel("Individual acquired spectrum index")
fig.axes[4].set_xlabel("Chemical shift (ppm)")
# Out:
# Text(0.5, 0, 'Chemical shift (ppm)')

# %%
tmp_fig = plt.figure(132020)
tmpax = tmp_fig.subplots()
lll = tmpax.plot([0, 1], [0, 1], 'green', [0, 1], [0, 1], 'red', [0, 1])

fig.axes[4].legend(lll, ["Accepted", "Rejected"], bbox_to_anchor=(0, 1, 1., .102), loc=3, ncol=2)
fig.tight_layout()

# annotations...
props = dict(boxstyle='square', facecolor='white', alpha=0.9, edgecolor='grey')

xlim = fig.axes[0].get_xlim()
ylim = fig.axes[0].get_ylim()
fig.axes[0].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.06, 
                     "A.",
                     fontsize=12,
                     bbox=props)

xlim = fig.axes[1].get_xlim()
ylim = fig.axes[1].get_ylim()
fig.axes[1].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.06, 
                     "B.",
                     fontsize=12,
                     bbox=props)

xlim = fig.axes[2].get_xlim()
ylim = fig.axes[2].get_ylim()
fig.axes[2].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.06, 
                     "C.",
                     fontsize=12,
                     bbox=props)

xlim = fig.axes[3].get_xlim()
ylim = fig.axes[3].get_ylim()
fig.axes[3].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.06, 
                     "D.",
                     fontsize=12,
                     bbox=props)

xlim = fig.axes[4].get_xlim()
ylim = fig.axes[4].get_ylim()
fig.axes[4].text(xlim[0] - (xlim[0]-xlim[1])*0.04, 
                     ylim[0] + (ylim[1]-ylim[0])*0.04, 
                     "E.",
                     fontsize=12,
                     bbox=props)

fig.savefig("./notebooks/figs/fig_data_rej_motion.svg")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
acqdur = ((s.sequence.tr / 1000.0 ) * 64) / 60
print("* motion happen after %f min of acquisition!" % acqdur)
# Out:
# * motion happen after 7.040000 min of acquisition!
