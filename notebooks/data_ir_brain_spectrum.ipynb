# %%
import os
os.chdir("/home/tangir/crmbm/python/pastis")

from IPython import get_ipython
get_ipython().magic("clear")

import matplotlib.pylab as plt
import mrs.reco as reco
import mrs.log as log
import numpy as np

plt.close("all")
plt.rcParams['figure.dpi'] = 75
plt.rcParams['figure.max_open_warning'] = 1000
plt.rcParams["figure.figsize"] = [8, 6]
# get_ipython().magic("matplotlib inline")
get_ipython().magic("matplotlib notebook")
log.setLevel(log.INFO)
# Out:
# (DEBUG) Loaded backend nbAgg version unknown.

# %% [markdown]
# # IR sLASER on brain
# 23/01/2019 - 347-re-p1-moelle - Renaud x

# %%
p = reco.pipeline("brain")

p.job_list.remove(p.job["data_rejecting"])
p.settings["display"] = True

p.dataset[0]["legend"] = "sLASER 10:2 IR TE=40ms"
p.dataset[0]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID216_slaser_R_N=10_2_longTE_SNR+++_FID50575.dat",
                                "/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID218_slaser_R_N=10_2_longTE_SNR+++_FID50577.dat"]

p.dataset[1]["legend"] = "sLASER 10:2 IR TE=30ms"
p.dataset[1]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID221_slaser_R_N=10_2_longTE_SNR+++_FID50580.dat",
                                "/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID222_slaser_R_N=10_2_longTE_SNR+++_FID50581.dat"]

p.dataset[2]["legend"] = "STEAM IR TE=3ms"
p.dataset[2]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID224_steam_shortTE_SNR+_FID50583.dat",
                                "/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID226_steam_shortTE_SNR+_FID50585.dat"]

p.dataset[3]["legend"] = "sLASER 10:2 TE=30ms"
p.dataset[3]["raw"]["files"] = ["/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID228_slaser_R_N=10_2_longTE_SNR+++_FID50587.dat",
                                "/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID229_slaser_R_N=10_2_longTE_SNR+++_FID50588.dat"]
p.dataset[3]["dcm"]["files"] = ["/home/tangir/crmbm/acq/347-re-p1-moelle/20200123/01_0022_slaser-r-n",
                                "/home/tangir/crmbm/acq/347-re-p1-moelle/20200123/01_0023_slaser-r-n"]

p.settings["datasets_indexes"] = [0, 1, 3]
p.run()
# Out:
# (INFO)  pipeline.load_template: load pipeline from template file [brain.pkl]...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: checking datasets...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: dataset[0]:
# (INFO)  pipeline.run:   legend = sLASER 10:2 IR TE=40ms
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID216_slaser_R_N=10_2_longTE_SNR+++_FID50575.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID218_slaser_R_N=10_2_longTE_SNR+++_FID50577.dat
# (INFO)  pipeline.run:   dicom #1 [REF] = None
# (INFO)  pipeline.run: dataset[1]:
# (INFO)  pipeline.run:   legend = sLASER 10:2 IR TE=30ms
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID221_slaser_R_N=10_2_longTE_SNR+++_FID50580.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID222_slaser_R_N=10_2_longTE_SNR+++_FID50581.dat
# (INFO)  pipeline.run:   dicom #1 [REF] = None
# (INFO)  pipeline.run: dataset[2]:
# (INFO)  pipeline.run:   legend = STEAM IR TE=3ms
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID224_steam_shortTE_SNR+_FID50583.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID226_steam_shortTE_SNR+_FID50585.dat
# (INFO)  pipeline.run:   dicom #1 [REF] = None
# (INFO)  pipeline.run: dataset[3]:
# (INFO)  pipeline.run:   legend = sLASER 10:2 TE=30ms
# (INFO)  pipeline.run:   raw #0 = /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID228_slaser_R_N=10_2_longTE_SNR+++_FID50587.dat
# (INFO)  pipeline.run:   raw #1 [REF] = /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID229_slaser_R_N=10_2_longTE_SNR+++_FID50588.dat
# (INFO)  pipeline.run:   dicom #0 = /home/tangir/crmbm/acq/347-re-p1-moelle/20200123/01_0022_slaser-r-n
# (INFO)  pipeline.run:   dicom #1 [REF] = /home/tangir/crmbm/acq/347-re-p1-moelle/20200123/01_0023_slaser-r-n
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data files...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 10:2 IR TE=40ms]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID216_slaser_R_N=10_2_longTE_SNR+++_FID50575.dat
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 48
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 34
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 39
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 37
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 38
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 43
#   match = re.findall(rgx, header_string)
# /home/tangir/miniconda/envs/py37/lib/python3.7/site-packages/suspect/io/twix.py:115: FutureWarning: Possible nested set at position 41
#   match = re.findall(rgx, header_string)
# (INFO)  reco.py.__new__: read a (128, 32, 8192) vector
# (WARNING) SIEMENS_TWIX_reader_syngo_MR_B17._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 10:2 IR TE=40ms]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID218_slaser_R_N=10_2_longTE_SNR+++_FID50577.dat
# (INFO)  reco.py.__new__: read a (8, 32, 8192) vector
# (WARNING) SIEMENS_TWIX_reader_syngo_MR_B17._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (8, 32, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 10:2 IR TE=30ms]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID221_slaser_R_N=10_2_longTE_SNR+++_FID50580.dat
# (INFO)  reco.py.__new__: read a (64, 32, 8192) vector
# (WARNING) SIEMENS_TWIX_reader_syngo_MR_B17._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 10:2 IR TE=30ms]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID222_slaser_R_N=10_2_longTE_SNR+++_FID50581.dat
# (INFO)  reco.py.__new__: read a (8, 32, 8192) vector
# (WARNING) SIEMENS_TWIX_reader_syngo_MR_B17._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (8, 32, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 10:2 TE=30ms]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID228_slaser_R_N=10_2_longTE_SNR+++_FID50587.dat
# (INFO)  reco.py.__new__: read a (64, 32, 8192) vector
# (WARNING) SIEMENS_TWIX_reader_syngo_MR_B17._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 10:2 TE=30ms]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID229_slaser_R_N=10_2_longTE_SNR+++_FID50588.dat
# (INFO)  reco.py.__new__: read a (8, 32, 8192) vector
# (WARNING) SIEMENS_TWIX_reader_syngo_MR_B17._get_sequence_acquisition_time_effective: cannot extract effective acquisition time from a TWIX file :(
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (8, 32, 8192) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading data [sLASER 10:2 TE=30ms]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/347-re-p1-moelle/20200123/01_0022_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)
# (INFO)  pipeline.run: reading ref. data [sLASER 10:2 TE=30ms]
# (INFO)  reco.py.__new__: reading data file...
# (INFO)  reco.py.__new__: /home/tangir/crmbm/acq/347-re-p1-moelle/20200123/01_0023_slaser-r-n
# (INFO)  reco.py.__new__: read a (1, 1, 4096) vector
# (INFO)  metabolite_basis_set.__init__: initializing metabolite database...
# (INFO)  metabolite_basis_set._read_xls_file: reading metabolite basis set from XLS file...
# (INFO)  pipeline.run: got a (1, 1, 4096) vector
# (INFO) ----------------------------------------
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: reading your job list...
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: #0 phasing
# (INFO)  pipeline.run: #1 scaling intensity
# (INFO)  pipeline.run: #2 channel-combining
# (INFO)  pipeline.run: #3 estimating noise level
# (INFO)  pipeline.run: #4 zero-filling
# (INFO)  pipeline.run: #5 frequency realigning
# (INFO)  pipeline.run: #6 averaging
# (INFO)  pipeline.run: #7 frequency shifting
# (INFO)  pipeline.run: #8 cropping
# (INFO)  pipeline.run: #9 displaying
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: running job list...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#0 sLASER 10:2 IR TE=40ms [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (INFO)  pipeline._analyze: post-phasing SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 2.39
# (INFO)  pipeline._analyze: post-phasing LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-scaling intensity SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 2.39
# (INFO)  pipeline._analyze: post-scaling intensity LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-channel-combining SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 2.39
# (INFO)  pipeline._analyze: post-channel-combining LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: estimating noise level on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# (INFO)  MRSData2.analyze_noise_nd: noise level = 3.30E+00
# (INFO)  MRSData2.analyze_noise_nd: noise level = 1.24E+01
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-estimating noise level SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 2.39
# (INFO)  pipeline._analyze: post-estimating noise level LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-zero-filling SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 2.46
# (INFO)  pipeline._analyze: post-zero-filling LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# realigning: ██████████████████████████████ done.
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency realigning SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 2.06
# (INFO)  pipeline._analyze: post-frequency realigning LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-averaging SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 2.06
# (INFO)  pipeline._analyze: post-averaging LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency shifting on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency shifting SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 2.02
# (INFO)  pipeline._analyze: post-frequency shifting LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: cropping on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-cropping SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 3.29
# (INFO)  pipeline._analyze: post-cropping LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: displaying on [#0 sLASER 10:2 IR TE=40ms [RAW]]...
# <img src="data:image/png;base64,..." width="640">
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#1 sLASER 10:2 IR TE=30ms [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-phasing SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 2.09
# (INFO)  pipeline._analyze: post-phasing LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-scaling intensity SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 2.09
# (INFO)  pipeline._analyze: post-scaling intensity LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-channel-combining SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 2.09
# (INFO)  pipeline._analyze: post-channel-combining LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: estimating noise level on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# (INFO)  MRSData2.analyze_noise_nd: noise level = 4.69E+00
# (INFO)  MRSData2.analyze_noise_nd: noise level = 1.53E+01
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-estimating noise level SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 2.09
# (INFO)  pipeline._analyze: post-estimating noise level LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-zero-filling SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 2.16
# (INFO)  pipeline._analyze: post-zero-filling LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# realigning: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency realigning SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 1.87
# (INFO)  pipeline._analyze: post-frequency realigning LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-averaging SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 1.87
# (INFO)  pipeline._analyze: post-averaging LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency shifting on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency shifting SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 2.15
# (INFO)  pipeline._analyze: post-frequency shifting LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: cropping on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-cropping SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 3.35
# (INFO)  pipeline._analyze: post-cropping LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: displaying on [#1 sLASER 10:2 IR TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#2 sLASER 10:2 TE=30ms [RAW]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#2 sLASER 10:2 TE=30ms [RAW]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-phasing SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.76
# (INFO)  pipeline._analyze: post-phasing LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#2 sLASER 10:2 TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-scaling intensity SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.76
# (INFO)  pipeline._analyze: post-scaling intensity LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#2 sLASER 10:2 TE=30ms [RAW]]...
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-channel-combining SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.76
# (INFO)  pipeline._analyze: post-channel-combining LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: estimating noise level on [#2 sLASER 10:2 TE=30ms [RAW]]...
# (INFO)  MRSData2.analyze_noise_nd: noise level = 4.50E+00
# (INFO)  MRSData2.analyze_noise_nd: noise level = 1.52E+01
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-estimating noise level SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.76
# (INFO)  pipeline._analyze: post-estimating noise level LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#2 sLASER 10:2 TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-zero-filling SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.97
# (INFO)  pipeline._analyze: post-zero-filling LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#2 sLASER 10:2 TE=30ms [RAW]]...
# realigning: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency realigning SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 11.56
# (INFO)  pipeline._analyze: post-frequency realigning LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 6.10
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#2 sLASER 10:2 TE=30ms [RAW]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-averaging SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 11.56
# (INFO)  pipeline._analyze: post-averaging LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 6.10
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency shifting on [#2 sLASER 10:2 TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency shifting SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 11.57
# (INFO)  pipeline._analyze: post-frequency shifting LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 6.10
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: cropping on [#2 sLASER 10:2 TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-cropping SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 20.05
# (INFO)  pipeline._analyze: post-cropping LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 7.32
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: displaying on [#2 sLASER 10:2 TE=30ms [RAW]]...
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline.run: processing [#2 sLASER 10:2 TE=30ms [DCM]]
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: phasing on [#2 sLASER 10:2 TE=30ms [DCM]]...
# phasing: ██████████████████████████████ done.
# (WARNING) MRSData2.correct_phase_3d: you want to phase data based on ref. data but no such data is available!
# phasing: ██████████████████████████████ done.
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-phasing SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 9.83
# (INFO)  pipeline._analyze: post-phasing LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: scaling intensity on [#2 sLASER 10:2 TE=30ms [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-scaling intensity SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 9.83
# (INFO)  pipeline._analyze: post-scaling intensity LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: channel-combining on [#2 sLASER 10:2 TE=30ms [DCM]]...
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (WARNING) MRSData2.correct_combine_channels_3d: you want to channel-combine data based on ref. data but no such data is available!
# (WARNING) MRSData2.correct_combine_channels_3d: this is a single-channel signal, no need to recombine this!
# (WARNING) MRSData2.correct_combine_channels_3d: reshaped to (1, 4096)
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-channel-combining SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 9.83
# (INFO)  pipeline._analyze: post-channel-combining LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: estimating noise level on [#2 sLASER 10:2 TE=30ms [DCM]]...
# (INFO)  MRSData2.analyze_noise_nd: noise level = 1.07E+01
# (INFO)  MRSData2.analyze_noise_nd: noise level = 5.58E+02
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-estimating noise level SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 9.83
# (INFO)  pipeline._analyze: post-estimating noise level LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: zero-filling on [#2 sLASER 10:2 TE=30ms [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-zero-filling SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 9.85
# (INFO)  pipeline._analyze: post-zero-filling LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency realigning on [#2 sLASER 10:2 TE=30ms [DCM]]...
# (WARNING) MRSData2.correct_realign_2d: single-shot signal, cannot realign this!
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency realigning SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 9.85
# (INFO)  pipeline._analyze: post-frequency realigning LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: averaging on [#2 sLASER 10:2 TE=30ms [DCM]]...
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (WARNING) MRSData2.correct_average_2d: single-shot signal, nothing to average!
# (WARNING) MRSData2.correct_average_2d: reshaped to a (16384,) vector
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-averaging SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 9.85
# (INFO)  pipeline._analyze: post-averaging LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: frequency shifting on [#2 sLASER 10:2 TE=30ms [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-frequency shifting SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 9.58
# (INFO)  pipeline._analyze: post-frequency shifting LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.54
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: cropping on [#2 sLASER 10:2 TE=30ms [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-cropping SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 13.66
# (INFO)  pipeline._analyze: post-cropping LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.85
# (INFO) ----------------------------------------
# (INFO)
# (INFO) ----------------------------------------
# (INFO)  pipeline._run_job: displaying on [#2 sLASER 10:2 TE=30ms [DCM]]...
# (INFO) ----------------------------------------
# (INFO)  pipeline._analyze: post-displaying SNR of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 3.29
# (INFO)  pipeline._analyze: post-displaying LW of [#0 sLASER 10:2 IR TE=40ms [RAW]] = 0.00
# (INFO)  pipeline._analyze: post-displaying SNR of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 3.35
# (INFO)  pipeline._analyze: post-displaying LW of [#1 sLASER 10:2 IR TE=30ms [RAW]] = 0.00
# (INFO)  pipeline._analyze: post-displaying SNR of [#2 sLASER 10:2 TE=30ms [RAW]] = 20.05
# (INFO)  pipeline._analyze: post-displaying LW of [#2 sLASER 10:2 TE=30ms [RAW]] = 7.32
# (INFO)  pipeline._analyze: post-displaying SNR of [#2 sLASER 10:2 TE=30ms [DCM]] = 13.66
# (INFO)  pipeline._analyze: post-displaying LW of [#2 sLASER 10:2 TE=30ms [DCM]] = 8.85
# (INFO)  pipeline.display_analyze_results: displaying SNR and linewidth final results...
# (INFO)  pipeline.get_analyze_results: converting analyze results to arrays...
# (INFO) ----------------------------------------
# RAW / DCM dataset        	SNR (u.a)           	LW (Hz)             	ref. data LW (Hz)
#
# #0 sLASER 10:2 IR TE=40ms	3.29 / nan          	0.00 / nan          	12.21 / nan
# #1 sLASER 10:2 IR TE=30ms	3.35 / nan          	0.00 / nan          	13.43 / nan
# #2 sLASER 10:2 TE=30ms   	20.05 / 13.66       	7.32 / 8.85         	12.82 / 12.51
# (INFO) ----------------------------------------
# <img src="data:image/png;base64,..." width="640">
# (INFO)  pipeline.run: pipeline terminated!
# (INFO)  pipeline.run: returning processed signals!
# [{'legend': '#0 sLASER 10:2 IR TE=40ms',
#   'raw': {'files': ['/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID216_slaser_R_N=10_2_longTE_SNR+++_FID50575.dat',
#     '/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID218_slaser_R_N=10_2_longTE_SNR+++_FID50577.dat'],
#    'data': MRSData2([-17.98418665 +4.27345528j, -29.82893513+17.73637254j,
#              -56.95543128+24.06636237j, ...,   5.23760972 -4.557158j  ,
#                5.36736625 +2.80941262j,  -0.14406567 +1.4310815j ]),
#    'analysis_results': {'phasing': {'snr': 2.387610469196275, 'lw': 0.0},
#     'scaling intensity': {'snr': 2.387610469196276, 'lw': 0.0},
#     'channel-combining': {'snr': 2.387610469196276, 'lw': 0.0},
#     'estimating noise level': {'snr': 2.387610469196276, 'lw': 0.0},
#     'zero-filling': {'snr': 2.464581651330241, 'lw': 0.0},
#     'frequency realigning': {'snr': 2.064157055526812, 'lw': 0.0},
#     'averaging': {'snr': 2.064157055526812, 'lw': 0.0},
#     'frequency shifting': {'snr': 2.017115668708476, 'lw': 0.0},
#     'cropping': {'snr': 3.2899319725476057, 'lw': 0.0}},
#    'ref_data_analysis_results': {'snr': 465.0810305864636,
#     'lw': 12.20703125000001}},
#   'dcm': {'files': [None, None],
#    'data': None,
#    'analysis_results': None,
#    'ref_data_analysis_results': None},
#   'physio_file': None,
#   'imaging_file': None,
#   'resp_bpm': None,
#   'heart_bpm': None,
#   'comment': None},
#  {'legend': '#1 sLASER 10:2 IR TE=30ms',
#   'raw': {'files': ['/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID221_slaser_R_N=10_2_longTE_SNR+++_FID50580.dat',
#     '/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID222_slaser_R_N=10_2_longTE_SNR+++_FID50581.dat'],
#    'data': MRSData2([ 18.07574573 -6.8031961j ,   9.89377714+36.78641331j,
#              -32.78964616+61.15865828j, ...,   0.70098637 -1.39381952j,
#                2.29299779 +0.29440212j,  -2.52483702 +4.26916235j]),
#    'analysis_results': {'phasing': {'snr': 2.088767947161422, 'lw': 0.0},
#     'scaling intensity': {'snr': 2.0887679471614224, 'lw': 0.0},
#     'channel-combining': {'snr': 2.0887679471614224, 'lw': 0.0},
#     'estimating noise level': {'snr': 2.0887679471614224, 'lw': 0.0},
#     'zero-filling': {'snr': 2.1630225564429497, 'lw': 0.0},
#     'frequency realigning': {'snr': 1.8671639440062258, 'lw': 0.0},
#     'averaging': {'snr': 1.8671639440062258, 'lw': 0.0},
#     'frequency shifting': {'snr': 2.146354526773412, 'lw': 0.0},
#     'cropping': {'snr': 3.3492810975261356, 'lw': 0.0}},
#    'ref_data_analysis_results': {'snr': 719.8394000845778,
#     'lw': 13.427734375000224}},
#   'dcm': {'files': [None, None],
#    'data': None,
#    'analysis_results': None,
#    'ref_data_analysis_results': None},
#   'physio_file': None,
#   'imaging_file': None,
#   'resp_bpm': None,
#   'heart_bpm': None,
#   'comment': None},
#  {'legend': '#2 sLASER 10:2 TE=30ms',
#   'raw': {'files': ['/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID228_slaser_R_N=10_2_longTE_SNR+++_FID50587.dat',
#     '/home/tangir/crmbm/acq_twix/347-re-p1-moelle/meas_MID229_slaser_R_N=10_2_longTE_SNR+++_FID50588.dat'],
#    'data': MRSData2([316.04589878 +27.45511852j, 286.6739512 +110.54245651j,
#              221.64591063+162.16260081j, ...,  -2.57267076  -3.43192942j,
#                4.57995613  +0.83254213j,  -3.54353712  +3.76922076j]),
#    'analysis_results': {'phasing': {'snr': 8.764552014509789,
#      'lw': 8.54492187500044},
#     'scaling intensity': {'snr': 8.764552014509789, 'lw': 8.54492187500044},
#     'channel-combining': {'snr': 8.764552014509789, 'lw': 8.54492187500044},
#     'estimating noise level': {'snr': 8.764552014509789,
#      'lw': 8.54492187500044},
#     'zero-filling': {'snr': 8.972514813061245, 'lw': 8.54492187500044},
#     'frequency realigning': {'snr': 11.564702245790448,
#      'lw': 6.103515624999409},
#     'averaging': {'snr': 11.564702245790448, 'lw': 6.103515624999409},
#     'frequency shifting': {'snr': 11.570313693138656, 'lw': 6.103515624999409},
#     'cropping': {'snr': 20.047139489288043, 'lw': 7.324218749999925}},
#    'ref_data_analysis_results': {'snr': 5880.940926421865,
#     'lw': 12.817382812499606}},
#   'dcm': {'files': ['/home/tangir/crmbm/acq/347-re-p1-moelle/20200123/01_0022_slaser-r-n',
#     '/home/tangir/crmbm/acq/347-re-p1-moelle/20200123/01_0023_slaser-r-n'],
#    'data': MRSData2([ 1.04091833e+03 -25.6863327j ,  6.49044508e+02+461.5061099j ,
#               1.80525454e+02+499.01284062j, ...,
#               1.38429062e-01  -1.5101886j ,  3.47290391e+01 -17.34990337j,
#              -2.51623573e+01 -11.51448672j]),
#    'analysis_results': {'phasing': {'snr': 9.828423309192846,
#      'lw': 8.544921874999913},
#     'scaling intensity': {'snr': 9.828423309192846, 'lw': 8.544921874999913},
#     'channel-combining': {'snr': 9.828423309192846, 'lw': 8.544921874999913},
#     'estimating noise level': {'snr': 9.828423309192846,
#      'lw': 8.544921874999913},
#     'zero-filling': {'snr': 9.85087823123514, 'lw': 8.544921874999913},
#     'frequency realigning': {'snr': 9.85087823123514, 'lw': 8.544921874999913},
#     'averaging': {'snr': 9.85087823123514, 'lw': 8.544921874999913},
#     'frequency shifting': {'snr': 9.583878980433566, 'lw': 8.544921874999913},
#     'cropping': {'snr': 13.66462067913114, 'lw': 8.850097656250306}},
#    'ref_data_analysis_results': {'snr': 4591.672686341221,
#     'lw': 12.51220703124974}},
#   'physio_file': None,
#   'imaging_file': None,
#   'resp_bpm': None,
#   'heart_bpm': None,
#   'comment': None}]

# %%
plt.close("all")

p.dataset[0]["raw"]["data"].correct_zerofill_nd().display_spectrum_1d(54237, display_range=[1, 4.5], allowed_apodization=20)
p.dataset[1]["raw"]["data"].correct_zerofill_nd().display_spectrum_1d(54237, display_range=[1, 4.5], allowed_apodization=20)
p.dataset[2]["raw"]["data"].correct_zerofill_nd().display_spectrum_1d(54237, display_range=[1, 4.5], allowed_apodization=5)

plt.ylim([-1000, 10000])

# line color
plt.figure(54237).axes[0].get_lines()[0].set_color('black')
plt.figure(54237).axes[0].get_lines()[0].set_linestyle("-.")
plt.figure(54237).axes[0].get_lines()[1].set_color('black')
plt.figure(54237).axes[0].get_lines()[1].set_linestyle("--")
plt.figure(54237).axes[0].get_lines()[2].set_color('black')

plt.legend(["semi-LASER TE=30ms TI=950ms", "semi-LASER TE=40ms TI=950ms", "semi-LASER TE=30ms"])

plt.figure(54237).savefig("./notebooks/figs/fig_ir_brain.svg")
print("S19")
# Out:
# <img src="data:image/png;base64,..." width="640">
# S19
